# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import requests
import time
from datetime import datetime
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3
plt.rcParams['axes.titlesize'] = 18

# %%
t = pd.read_csv('downloaded-logs-20230405-141843.csv', delimiter=',')
t.head()
# Out:
#            insertId                              jsonPayload.blockHash  \
# 0  7f7vqugby3i4irj8  0xb8e8d5b6e3e863105ad777ba4d5ef8553825e3adebe7...
# 1  tfp1ulfz83ibfxvg  0xb8e8d5b6e3e863105ad777ba4d5ef8553825e3adebe7...
# 2  har7q2haqbfsf77z  0xb8e8d5b6e3e863105ad777ba4d5ef8553825e3adebe7...
# 3  toa15gqwm3t5idvr  0xb8e8d5b6e3e863105ad777ba4d5ef8553825e3adebe7...
# 4  kjhc6ids8tdyy26z  0xb8e8d5b6e3e863105ad777ba4d5ef8553825e3adebe7...
#
#    jsonPayload.contentLength  jsonPayload.headSlot jsonPayload.idArg  \
# 0                      84768               6157863               NaN
# 1                      84768               6157863               NaN
# 2                      84768               6157863               NaN
# 3                      84768               6157863               NaN
# 4                      84768               6157863               NaN
#
#   jsonPayload.level jsonPayload.method jsonPayload.mevBoostV  \
# 0             error         getPayload                v1.5.0
# 1             error         getPayload                v1.5.0
# 2             error         getPayload                v1.5.0
# 3             error         getPayload                v1.5.0
# 4             error         getPayload                v1.5.0
#
#    jsonPayload.msIntoSlot     jsonPayload.msg  ... receivedLocation  \
# 0                    7226  timestamp too late  ...              NaN
# 1                    6385  timestamp too late  ...              NaN
# 2                    6804  timestamp too late  ...              NaN
# 3                    5537  timestamp too late  ...              NaN
# 4                    5961  timestamp too late  ...              NaN
#
#    resource.labels.cluster_name resource.labels.container_name  \
# 0                        midori                   proposer-api
# 1                        midori                   proposer-api
# 2                        midori                   proposer-api
# 3                        midori                   proposer-api
# 4                        midori                   proposer-api
#
#    resource.labels.location  resource.labels.namespace_name  \
# 0            europe-west1-b                         default
# 1            europe-west1-b                         default
# 2            europe-west1-b                         default
# 3            europe-west1-b                         default
# 4            europe-west1-b                         default
#
#         resource.labels.pod_name  resource.labels.project_id  resource.type  \
# 0  proposer-api-846b5f58d9-ddtsc           ultra-sound-relay  k8s_container
# 1  proposer-api-846b5f58d9-ddtsc           ultra-sound-relay  k8s_container
# 2  proposer-api-846b5f58d9-ddtsc           ultra-sound-relay  k8s_container
# 3  proposer-api-846b5f58d9-p6xs2           ultra-sound-relay  k8s_container
# 4  proposer-api-846b5f58d9-8mdbs           ultra-sound-relay  k8s_container
#
#   severity             timestamp
# 0    ERROR  2023-04-05T18:13:18Z
# 1    ERROR  2023-04-05T18:13:17Z
# 2    ERROR  2023-04-05T18:13:17Z
# 3    ERROR  2023-04-05T18:13:16Z
# 4    ERROR  2023-04-05T18:13:16Z
#
# [5 rows x 34 columns]

# %%
slots = np.asarray(list(set(t['jsonPayload.slot'])))
slots = np.sort(slots)
len(slots)
# Out:
# 30

# %%
slots = np.sort(slots)

# %%
slots
# Out:
# array([6154758, 6154798, 6154806, 6155065, 6155184, 6155206, 6155262,
#        6155382, 6155444, 6155474, 6155942, 6156033, 6156063, 6156084,
#        6156253, 6156323, 6156433, 6156520, 6156552, 6156607, 6156731,
#        6156800, 6156919, 6157155, 6157170, 6157184, 6157584, 6157598,
#        6157719, 6157864])

# %%
res = []
for s in slots:
    time.sleep(0.1)
    url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
    headers = {'content-type': 'application/json'}
    r = requests.get(url, headers=headers)
    try: 
        code = r.json()['code']
        print(s, False)
        res.append((s, False))
    except KeyError:
        print(s, True)
        res.append((s, True))
# Out:
# 6154758 True
# 6154798 True
# 6154806 True
# 6155065 True
# 6155184 True
# 6155206 True
# 6155262 True
# 6155382 True
# 6155444 True
# 6155474 True
# 6155942 True
# 6156033 True
# 6156063 False
# 6156084 True
# 6156253 True
# 6156323 True
# 6156433 True
# 6156520 True
# 6156552 True
# 6156607 True
# 6156731 True
# 6156800 True
# 6156919 True
# 6157155 True
# 6157170 True
# 6157184 False
# 6157584 False
# 6157598 False
# 6157719 True
# 6157864 False

# %%
ignore 6156063, 6157584
slot=6157184 ms=13973 (could be the relay being down)
slot=6157598 ms=5524
slot=6157864 ms=5537
slot=6158720 ms=4482

# %%
slot=6154177 ms=4029
slot=6154560 ms=

# %%
res = np.asarray(res)

# %%
res
# Out:
# array([[6144827,       1],
#        [6144830,       1],
#        [6144832,       0],
#        ...,
#        [6148624,       1],
#        [6148625,       1],
#        [6148626,       1]])

# %%
res[:,1].sum(), len(res), len(res) - res[:,1].sum()
# Out:
# (1232, 1269, 37)

# %%
6148626 - 6144827
# Out:
# 3799

# %%
len(res), res[]

# %%
37/1269
# Out:
# 0.029156816390858944

# %% [markdown]
# ## post 3s

# %%
t = pd.read_csv('downloaded-logs-20230404-132958.csv', delimiter=',')
t.head()
# Out:
#            insertId                              jsonPayload.blockHash  \
# 0  qcp5erd2vpnrrrud  0x91a6011be8c01ca8b3da434490f49714d012bdf94656...
# 1  k23g10yoxoz9v1ym  0xe3b3f8f11dc7300dd7fea84ece939f63f960dfd70e5d...
# 2  x8rqwpc22vnlmoi0  0x87d16ce758de89213329d0f68c933a12664732ccd33d...
# 3  mc0o06mm8js0tecg  0x2d100c7e2326027a0fa344e835e92f9b67dbc9c1601d...
# 4  jzgo4obzf0426lmo  0xd2c42bf3d991a69e36ba79d481f1ebceed9f78d0059d...
#
#    jsonPayload.contentLength  jsonPayload.headSlot jsonPayload.idArg  \
# 0                      54037               6150442               NaN
# 1                      84765               6150438               NaN
# 2                      57880               6150434               NaN
# 3                      84755               6150428               NaN
# 4                      84763               6150424               NaN
#
#   jsonPayload.level jsonPayload.method jsonPayload.mevBoostV  \
# 0              info         getPayload                 1.4.0
# 1              info         getPayload    v1.3.2-44-g08bd891
# 2              info         getPayload                v1.5.0
# 3              info         getPayload                v1.5.0
# 4              info         getPayload                     -
#
#    jsonPayload.msIntoSlot              jsonPayload.msg  ... receivedLocation  \
# 0                    1857  getPayload request received  ...              NaN
# 1                     700  getPayload request received  ...              NaN
# 2                     947  getPayload request received  ...              NaN
# 3                     811  getPayload request received  ...              NaN
# 4                     671  getPayload request received  ...              NaN
#
#    resource.labels.cluster_name resource.labels.container_name  \
# 0                        midori                   proposer-api
# 1                        midori                   proposer-api
# 2                        midori                   proposer-api
# 3                        midori                   proposer-api
# 4                        midori                   proposer-api
#
#    resource.labels.location resource.labels.namespace_name  \
# 0            europe-west1-b                        default
# 1            europe-west1-b                        default
# 2            europe-west1-b                        default
# 3            europe-west1-b                        default
# 4            europe-west1-b                        default
#
#        resource.labels.pod_name resource.labels.project_id  resource.type  \
# 0  proposer-api-dbd9cb97f-6zdz6          ultra-sound-relay  k8s_container
# 1  proposer-api-dbd9cb97f-m7mcw          ultra-sound-relay  k8s_container
# 2  proposer-api-dbd9cb97f-mf8dr          ultra-sound-relay  k8s_container
# 3  proposer-api-dbd9cb97f-mf8dr          ultra-sound-relay  k8s_container
# 4  proposer-api-dbd9cb97f-6zdz6          ultra-sound-relay  k8s_container
#
#   severity             timestamp
# 0     INFO  2023-04-04T17:29:00Z
# 1     INFO  2023-04-04T17:28:11Z
# 2     INFO  2023-04-04T17:27:23Z
# 3     INFO  2023-04-04T17:26:11Z
# 4     INFO  2023-04-04T17:25:23Z
#
# [5 rows x 31 columns]

# %%
slots = np.asarray(list(set(t['jsonPayload.slot'])))
len(slots)
# Out:
# 718

# %%
res = []
for s in slots:
    time.sleep(0.1)
    url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
    headers = {'content-type': 'application/json'}
    r = requests.get(url, headers=headers)
    try: 
        code = r.json()['code']
        print(s, False)
        res.append((s, False))
    except KeyError:
        print(s, True)
        res.append((s, True))
# Out:
# 6150144 True
# 6150147 True
# 6150149 True
# 6150151 True
# 6150157 True
# 6150158 True
# 6150160 True
# 6150162 True
# 6150163 True
# 6150164 True
# 6150165 True
# 6150166 True
# 6150167 True
# 6150169 True
# 6150171 True
# 6150173 True
# 6150175 True
# 6150176 True
# 6150177 True
# 6150178 True
# 6150181 True
# 6150182 True
# 6150183 True
# 6150191 True
# 6150198 True
# 6150199 True
# 6150201 True
# 6150202 True
# 6150205 True
# 6150208 True
# 6150217 True
# 6150222 True
# 6150229 True
# 6150233 True
# 6150238 True
# 6150240 True
# 6150243 True
# 6150247 True
# 6150248 True
# 6150253 True
# 6150255 True
# 6150260 True
# 6150262 True
# 6150264 True
# 6150265 True
# 6150268 True
# 6150270 True
# 6150275 True
# 6150279 True
# 6150280 True
# 6150281 True
# 6150293 True
# 6150295 True
# 6150297 True
# 6150298 True
# 6150304 True
# 6150305 True
# 6150309 True
# 6150313 True
# 6150315 True
# 6150316 True
# 6150327 True
# 6150328 True
# 6150331 True
# 6150332 True
# 6150339 True
# 6150341 True
# 6150342 True
# 6150345 True
# 6150350 True
# 6150352 True
# 6150356 True
# 6150358 True
# 6150359 True
# 6150361 True
# 6150369 True
# 6150370 True
# 6150371 True
# 6150377 True
# 6150378 True
# 6150380 True
# 6150381 True
# 6150390 True
# 6150391 True
# 6150393 True
# 6148347 True
# 6150396 True
# 6150397 True
# 6150398 True
# 6149982 True
# 6149984 True
# 6149997 True
# 6149998 True
# 6150000 True
# 6150001 True
# 6150008 True
# 6150009 True
# 6150010 True
# 6150013 True
# 6150014 True
# 6150019 True
# 6150022 True
# 6150025 True
# 6150027 True
# 6150033 True
# 6150034 True
# 6150035 True
# 6150045 True
# 6150047 True
# 6150050 True
# 6150053 True
# 6150056 True
# 6150058 True
# 6150060 True
# 6150062 True
# 6150063 True
# 6150067 True
# 6150071 True
# 6150077 True
# 6150078 True
# 6150081 True
# 6150084 True
# 6150086 True
# 6150093 True
# 6150098 True
# 6150102 True
# 6150106 True
# 6150107 True
# 6150109 True
# 6150118 True
# 6150125 True
# 6150127 True
# 6150130 True
# 6150133 True
# 6150135 True
# 6150138 True
# 6150139 True
# 6150142 True
# 6150143 True

# %%
res = np.asarray(res)

# %%
res[:,1].sum(), len(res), len(res) - res[:,1].sum()
# Out:
# (714, 718, 4)

# %%
[v for v in res if v[1] == 0]
# Out:
# [array([6148669,       0]),
#  array([6148694,       0]),
#  array([6149011,       0]),
#  array([6149120,       0])]

# %%
4/718
# Out:
# 0.005571030640668524

# %%
slots.max() - slots.min()
# Out:
# 2096

# %%
ms = t['jsonPayload.msIntoSlot']

# %%
f, ax = plt.subplots(figsize=(8,5))
ax.hist(ms[ms<8000], color='g', bins=100)

plt.show()

# %%
1857
# Out:
# 1857

# %%
t['jsonPayload.slot']
# Out:
# 0      6150443
# 1      6150439
# 2      6150435
# 3      6150429
# 4      6150425
#         ...
# 803    6148355
# 804    6148351
# 805    6148349
# 806    6148348
# 807    6148347
# Name: jsonPayload.slot, Length: 808, dtype: int64

# %%
17:29:02.344202

# %%
ms
# Out:
# 0      1857
# 1       700
# 2       947
# 3       811
# 4       671
#        ...
# 803    2271
# 804    1545
# 805     890
# 806     630
# 807     513
# Name: jsonPayload.msIntoSlot, Length: 808, dtype: int64

# %% [markdown]
# ## signed at

# %%
t = pd.read_csv('signedat.txt', delimiter='|', names=['signed_at'])
t['signed_at'] = pd.to_datetime(t['signed_at'], format="%Y-%m-%d %H:%M:%S.%f")
t['rounded'] = np.asarray([pd.Timestamp(x).round(freq='12S') for x in t['signed_at'].values])
# t['rounded2'] = np.asarray([pd.to_datetime(datetime.fromtimestamp(s)) for s in seconds])
t.head()
# Out:
#                    signed_at             rounded
# 0 2023-03-21 21:10:59.584453 2023-03-21 21:11:00
# 1 2023-03-21 21:11:11.732092 2023-03-21 21:11:12
# 2 2023-03-21 21:11:23.960128 2023-03-21 21:11:24
# 3 2023-03-21 21:11:47.739006 2023-03-21 21:11:48
# 4 2023-03-21 21:12:12.388894 2023-03-21 21:12:12

# %%
diffs = np.asarray([v.total_seconds() for v in t['rounded'] - t['signed_at']])
diffs += 1

# %%
plt.hist(diffs, bins=600)
plt.show()

# %%
diffs.max()
# Out:
# 6.978654

# %%
new = pd.read_csv('slots-0404-1.txt', names=['slots'])
new.head()
# Out:
#      slots
# 0  6148347
# 1  6148348
# 2  6148349
# 3  6148351
# 4  6148354

# %%
res2 = []
for s in new['slots']:
    time.sleep(0.1)
# 6151389 True
# 6151391 True
# 6151400 True
# 6151405 True
# 6151407 False
# 6151410 True
# 6151411 True
# 6151412 True
# 6151413 True
# 6151417 True
# 6151419 True
# 6151420 True
# 6151421 True
# 6151422 True
# 6151423 True
# 6151428 True
# 6151430 True
# 6151431 True
# 6151432 True
# 6151433 True
# 6151435 True
# 6151437 True
# 6151438 True
# 6151439 True
# 6151440 True
# 6151441 True
# 6151442 True
# 6151443 True
# 6151446 True
# 6151447 True
# 6151449 True
# 6151452 True
# 6151453 True
# 6151454 True
# 6151455 True
# 6151456 True
# 6151457 True
# 6151459 True
# 6151461 True
# 6151463 True
# 6151464 True
# 6151465 True
# 6151466 True
# 6151467 True
# 6151469 True
# 6151470 True
# 6151472 True
# 6151475 True
# 6151477 True
# 6151478 True
# 6151479 True
# 6151480 True
# 6151491 True
# 6151493 True
# 6151494 True
# 6151497 True
# 6151503 True
# 6151505 True
# 6151507 True
# 6151508 True
# 6151509 True
# 6151513 True
# 6151514 True
# 6151515 True
# 6151517 True
# 6151519 True
# 6151521 True
# 6151525 True
# 6151526 True
# 6151527 True
# 6151528 True
# 6151529 True
# 6151531 True
# 6151532 True
# 6151533 True
# 6151534 True
# 6151535 True
# 6151537 True
# 6151538 True
# 6151539 True
# 6151540 True
# 6151541 True
# 6151542 True
# 6151543 True
# 6151547 True
# 6151548 True
# 6151549 True
# 6151550 True
# 6151552 True
# 6151554 True
# 6151556 True
# 6151557 True
# 6151560 True
# 6151562 True
# 6151563 True
# 6151564 True
# 6151565 True
# 6151566 True
# 6151569 True
# 6151571 True
# 6151572 True
# 6151573 True
# 6151574 True
# 6151575 True
# 6151577 True
# 6151579 True
# 6151580 True
# 6151581 True
# 6151583 True
# 6151587 True
# 6151599 True
# 6151600 True
# 6151601 False
# 6151602 True
# 6151603 True
# 6151604 True
# 6151605 True
# 6151606 True
# 6151607 True
# 6151608 True
# 6151618 True
# 6151619 True
# 6151620 True
# 6151621 True
# 6151624 True
# 6151625 True
# 6151626 True
# 6151627 True
# 6151628 True
# 6151629 True

# %%
res2 = np.asarray(res2)

# %%
res2[:,1].sum(), len(res2), len(res2) - res2[:,1].sum()
# Out:
# (1830, 1849, 19)

# %%
3 / 1055
# Out:
# 0.002843601895734597

# %%
[v for v in res2 if v[1] == 0]
# Out:
# [array([6148504,       0]),
#  array([6148508,       0]),
#  array([6148526,       0]),
#  array([6148669,       0]),
#  array([6148694,       0]),
#  array([6148794,       0]),
#  array([6149011,       0]),
#  array([6149024,       0]),
#  array([6149120,       0]),
#  array([6149124,       0]),
#  array([6149345,       0]),
#  array([6150005,       0]),
#  array([6150065,       0]),
#  array([6150112,       0]),
#  array([6150337,       0]),
#  array([6150450,       0]),
#  array([6150904,       0]),
#  array([6151407,       0]),
#  array([6151601,       0])]

# %%
missing = [v[0] for v in res2 if v[1] == 0]
missing
# Out:
# [6148504,
#  6148508,
#  6148526,
#  6148669,
#  6148694,
#  6148794,
#  6149011,
#  6149024,
#  6149120,
#  6149124,
#  6149345,
#  6150005,
#  6150065,
#  6150112,
#  6150337,
#  6150450,
#  6150904,
#  6151407,
#  6151601]

# %%
slot=6148669 ms=3412
slot=6148694 ms=7036
slot=6149120 ms=3722

# %% [markdown]
# no getPayload called
# 6148504
# 6148508
# 6149024

# %%
4/718
# Out:
# 0.005571030640668524

# %%
slots.max() - slots.min()
# Out:
# 2096

# %%
delivered = pd.read_csv('downloaded-logs-20230404-192446.csv', delimiter=',')
delivered.head()
# Out:
#            insertId                              jsonPayload.blockHash  \
# 0  mb7854em49cu2y4k  0x21fd85b40faed4c20e225466a91047f7a08d58e67294...
# 1  jr7bwqktvuru4bs3  0xad15215b21e0376dd1ac4be59bb69e498484c65c31bb...
# 2  o0m4u2q8vwe8vspl  0xad15215b21e0376dd1ac4be59bb69e498484c65c31bb...
# 3  eh8s32t5rabln71o  0xad15215b21e0376dd1ac4be59bb69e498484c65c31bb...
# 4  n58rysgk6wf4gsao  0x3196815af79a0fbb120a6eb02e0a46401f4d9bdcbf48...
#
#    jsonPayload.contentLength  jsonPayload.headSlot jsonPayload.idArg  \
# 0                      43781               6152211               NaN
# 1                      84764               6152210               NaN
# 2                      84764               6152210               NaN
# 3                      84764               6152209               NaN
# 4                      70055               6152204               NaN
#
#   jsonPayload.level jsonPayload.method jsonPayload.mevBoostV  \
# 0              info         getPayload                 1.4.0
# 1              info         getPayload                     -
# 2              info         getPayload                     -
# 3              info         getPayload                     -
# 4              info         getPayload                v1.5.0
#
#    jsonPayload.msIntoSlot              jsonPayload.msg  ...  receivedLocation  \
# 0                     498  getPayload request received  ...               NaN
# 1                    4438  getPayload request received  ...               NaN
# 2                    3462  getPayload request received  ...               NaN
# 3                     719  getPayload request received  ...               NaN
# 4                    1765  getPayload request received  ...               NaN
#
#   resource.labels.cluster_name  resource.labels.container_name  \
# 0                       midori                    proposer-api
# 1                       midori                    proposer-api
# 2                       midori                    proposer-api
# 3                       midori                    proposer-api
# 4                       midori                    proposer-api
#
#    resource.labels.location resource.labels.namespace_name  \
# 0            europe-west1-b                        default
# 1            europe-west1-b                        default
# 2            europe-west1-b                        default
# 3            europe-west1-b                        default
# 4            europe-west1-b                        default
#
#        resource.labels.pod_name resource.labels.project_id  resource.type  \
# 0  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
# 1  proposer-api-ff84f4d76-7fm7r          ultra-sound-relay  k8s_container
# 2  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
# 3  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
# 4  proposer-api-ff84f4d76-pm49z          ultra-sound-relay  k8s_container
#
#   severity             timestamp
# 0     INFO  2023-04-04T23:22:47Z
# 1     INFO  2023-04-04T23:22:27Z
# 2     INFO  2023-04-04T23:22:26Z
# 3     INFO  2023-04-04T23:22:23Z
# 4     INFO  2023-04-04T23:21:24Z
#
# [5 rows x 33 columns]

# %%
failed = pd.read_csv('downloaded-logs-20230404-203142.csv', delimiter=',')
failed.head()
# Out:
#            insertId                              jsonPayload.blockHash  \
# 0  3dl85xet465ijznf  0x9200cb05479a639057dfe76b3c88d7f5023cae7baf31...
# 1  v2w1hwc52rgszrxq  0x9200cb05479a639057dfe76b3c88d7f5023cae7baf31...
# 2  dfknskzzxtixnnpi  0x392a8d235d2dfb791d91dee8765614f62bb73beef824...
# 3  ax13pzptq9wxkdnu  0x392a8d235d2dfb791d91dee8765614f62bb73beef824...
# 4  snaxdn0ht5ppw553  0x204608a5dd87a6ed474b51c2dc5746f948bccc936d3f...
#
#    jsonPayload.contentLength  jsonPayload.error  jsonPayload.headSlot  \
# 0                      84768                NaN               6152525
# 1                      84768                NaN               6152525
# 2                      84767                NaN               6152397
# 3                      84767                NaN               6152397
# 4                      84760                NaN               6152280
#
#   jsonPayload.idArg jsonPayload.level jsonPayload.method  \
# 0               NaN           warning         getPayload
# 1               NaN           warning         getPayload
# 2               NaN           warning         getPayload
# 3               NaN           warning         getPayload
# 4              lido           warning         getPayload
#
#   jsonPayload.mevBoostV  jsonPayload.msIntoSlot  ... receivedLocation  \
# 0                 1.3.1                   937.0  ...              NaN
# 1                 1.3.1                   937.0  ...              NaN
# 2                 1.3.1                   896.0  ...              NaN
# 3                 1.3.1                   896.0  ...              NaN
# 4                v1.5.0                  1421.0  ...              NaN
#
#   resource.labels.cluster_name  resource.labels.container_name  \
# 0                       midori                    proposer-api
# 1                       midori                    proposer-api
# 2                       midori                    proposer-api
# 3                       midori                    proposer-api
# 4                       midori                    proposer-api
#
#   resource.labels.location  resource.labels.namespace_name  \
# 0           europe-west1-b                         default
# 1           europe-west1-b                         default
# 2           europe-west1-b                         default
# 3           europe-west1-b                         default
# 4           europe-west1-b                         default
#
#        resource.labels.pod_name resource.labels.project_id  resource.type  \
# 0  proposer-api-ff84f4d76-7fm7r          ultra-sound-relay  k8s_container
# 1  proposer-api-ff84f4d76-7fm7r          ultra-sound-relay  k8s_container
# 2  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
# 3  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
# 4  proposer-api-ff84f4d76-8ft7x          ultra-sound-relay  k8s_container
#
#   severity             timestamp
# 0  WARNING  2023-04-05T00:25:36Z
# 1  WARNING  2023-04-05T00:25:35Z
# 2  WARNING  2023-04-05T00:00:00Z
# 3  WARNING  2023-04-04T23:59:59Z
# 4  WARNING  2023-04-04T23:36:36Z
#
# [5 rows x 35 columns]

# %%
dslots.max()
# Out:
# 6152212

# %%
for m in missing:
    if m in dslots and m not in fslots:
        print(m)
# Out:
# 6148669
# 6148694
# 6149120
# 6150904

# %%
fslots
# Out:
# array([6145664, 6147073, 6142720, 6142466, 6151812, 6141959, 6139911,
#        6151306, 6147853, 6147597, 6151567, 6141200, 6151571, 6149011,
#        6143125, 6142612, 6151962, 6150811, 6139930, 6144671, 6152230,
#        6140841, 6144683, 6149549, 6141359, 6146864, 6140338, 6144435,
#        6141876, 6140979, 6143422, 6143807, 6142016, 6151234, 6150850,
#        6150981, 6141127, 6151117, 6152398, 6152526, 6141007, 6140749,
#        6150866, 6140754, 6152281, 6141529, 6151775, 6140517, 6141286,
#        6149352, 6151401, 6146666, 6140397, 6150000, 6140400, 6147186,
#        6140534, 6140921, 6147455])

# %%
slot=6148669 ms=3412
slot=6148694 ms=7036
slot=6149120 ms=3722

# %%
delivered.keys()
# Out:
# Index(['insertId', 'jsonPayload.blockHash', 'jsonPayload.contentLength',
#        'jsonPayload.headSlot', 'jsonPayload.idArg', 'jsonPayload.level',
#        'jsonPayload.method', 'jsonPayload.mevBoostV', 'jsonPayload.msIntoSlot',
#        'jsonPayload.msg', 'jsonPayload.requestTimestamp',
#        'jsonPayload.service', 'jsonPayload.slot', 'jsonPayload.slotStartSec',
#        'jsonPayload.ua', 'jsonPayload.version',
#        'labels."compute.googleapis.com/resource_name"', 'labels."k8s-pod/app"',
#        'labels."k8s-pod/pod-template-hash"', 'labels."k8s-pod/project"',
#        'logName', 'receiveLocation', 'receiveTimestamp', 'receivedLocation',
#        'resource.labels.cluster_name', 'resource.labels.container_name',
#        'resource.labels.location', 'resource.labels.namespace_name',
#        'resource.labels.pod_name', 'resource.labels.project_id',
#        'resource.type', 'severity', 'timestamp'],
#       dtype='object')

# %%
dslots = np.asarray(list(set(delivered['jsonPayload.slot'])))
fslots = np.asarray(list(set(failed['jsonPayload.slot'])))

# %%
res = {}
for index, row in df.iterrows():
    s = row['jsonPayload.slot']
    if s in fslots:
        pass
    try:
        res[s].append()
    print(row['c1'], row['c2'])

# %%
len(dslots), len(fslots)
# Out:
# (2317, 59)

# %%
slots = np.asarray([s for s in dslots if s not in fslots])
len(slots)
# Out:
# 2292

# %%
slots
# Out:
# array([6152192, 6152193, 6152194, ..., 6152187, 6152190, 6152191])

# %%
plt.plot(slots)

# %%
res3 = []
for s in slots:
    if s < 6148342:
        pass
    time.sleep(0.1)
    url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
    headers = {'content-type': 'application/json'}
    r = requests.get(url, headers=headers)
    try: 
        code = r.json()['code']
        print(s, False)
        res3.append((s, False))
    except KeyError:
        print(s, True)
        res3.append((s, True))
# Out:
# 6152192 True
# 6152193 True
# 6152194 True
# 6152195 True
# 6152196 True
# 6152202 True
# 6152205 True
# 6152210 True
# 6152212 True
# 6144827 True
# 6144830 True
# 6144832 False
# 6144834 False
# 6144837 True
# 6144838 False
# 6144844 True
# 6144851 True
# 6144854 True
# 6144880 True
# 6144888 True
# 6144892 True
# 6144902 True
# 6144916 True
# 6144920 True
# 6144928 True
# 6144930 True
# 6144935 True
# 6144936 True
# 6144943 True
# 6144944 True
# 6144947 True
# 6144948 True
# 6144949 True
# 6144957 True
# 6144960 True
# 6144982 True
# 6144985 True
# 6144988 True
# 6144989 True
# 6144991 True
# 6145002 True
# 6145009 True
# 6145013 True
# 6145017 True
# 6145018 True
# 6145022 True
# 6145029 True
# 6145034 True
# 6145037 True
# 6145038 True
# 6145042 True
# 6145043 True
# 6145048 True
# 6145050 True
# 6145051 True
# 6145052 True
# 6145053 True
# 6145056 False
# 6145061 True
# 6145067 True
# 6145070 True
# 6145074 True
# 6145075 True
# 6145080 True
# 6145081 True
# 6145083 True
# 6145084 True
# 6145086 True
# 6145088 True
# 6145089 True
# 6145091 True
# 6145092 True
# 6145093 True
# 6145094 False
# 6145096 True
# 6145098 True
# 6145101 True
# 6145104 True
# 6145117 True
# 6145118 True
# 6145120 False
# 6145121 True
# 6145125 True
# 6145130 True
# 6145131 True
# 6145132 True
# 6145136 True
# 6145137 True
# 6145138 True
# 6145139 True
# 6145142 True
# 6145147 True
# 6145150 True
# 6145152 True
# 6145155 True
# 6145156 True
# 6145159 True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-ff30bd16a598> in <module>
#       6     url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
#       7     headers = {'content-type': 'application/json'}
# ----> 8     r = requests.get(url, headers=headers)
#       9     try:
#      10         code = r.json()['code']
#
# /usr/local/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     683
#     684         if not stream:
# --> 685             r.content
#     686
#     687         return r
#
# /usr/local/lib/python3.8/site-packages/requests/models.py in content(self)
#     827                 self._content = None
#     828             else:
# --> 829                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     830
#     831         self._content_consumed = True
#
# /usr/local/lib/python3.8/site-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     573         else:
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#     577                 if data:
#
# /usr/local/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# /usr/local/Cellar/python@3.8/3.8.16/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/local/Cellar/python@3.8/3.8.16/Frameworks/Python.framework/Versions/3.8/lib/python3.8/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/local/Cellar/python@3.8/3.8.16/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
toolate = pd.read_csv('downloaded-logs-20230404-212114.csv', delimiter=',')

# %%
slots = np.asarray(list(set(toolate['jsonPayload.slot'])))

# %%
slot=6148669 ms=3412
slot=6148694 ms=7036
slot=6149120 ms=3722

# %%
slots.min()
# Out:
# 6148369

# %%
6152818 - 6148369
# Out:
# 4449

# %%
4/1197
# Out:
# 0.003341687552213868

# %%
slot=6148669 ms=3412
slot=6148694 ms=7036
slot=6149120 ms=3722
slot=6152544 ms=3787

# %%
res3 = []
for s in slots:
    time.sleep(0.1)
    url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
    headers = {'content-type': 'application/json'}
    r = requests.get(url, headers=headers)
    try: 
        code = r.json()['code']
        print(s, False)
        res3.append((s, False))
    except KeyError:
        print(s, True)
        res3.append((s, True))
# Out:
# 6152576 True
# 6149120 False
# 6149891 True
# 6149383 True
# 6150793 True
# 6152586 True
# 6149515 True
# 6148369 True
# 6152210 True
# 6149651 True
# 6150166 True
# 6152605 True
# 6150685 True
# 6152352 True
# 6150945 True
# 6152355 True
# 6152099 True
# 6149032 True
# 6152108 True
# 6151215 True
# 6150831 True
# 6152369 True
# 6148527 True
# 6151991 True
# 6151479 True
# 6150779 True
# 6148796 True
# 6148669 False
# 6149823 True
# 6151489 True
# 6150465 True
# 6148674 True
# 6152135 True
# 6150984 True
# 6149961 True
# 6149707 True
# 6152530 True
# 6150738 True
# 6151638 True
# 6149975 True
# 6148694 False
# 6150623 True
# 6152544 False
# 6152545 True
# 6149471 True
# 6148471 True
# 6148837 True
# 6150504 True
# 6150511 True
# 6151153 True
# 6152691 True
# 6152692 True
# 6151669 True
# 6150644 True
# 6150647 True
# 6152443 True

# %% [markdown]
# ## too late post 4000MS

# %%
toolate = pd.read_csv('downloaded-logs-20230405-091939.csv', delimiter=',')

# %%
slots = np.asarray(list(set(toolate['jsonPayload.slot'])))

# %%
slots
# Out:
# array([6156033, 6156323, 6155942, 6155206, 6154758, 6154798, 6155184,
#        6155474, 6156084, 6155444, 6155382, 6154806, 6155065, 6156253,
#        6155262, 6156063])

# %%
6152818 - 6148369
# Out:
# 4449

# %%
4/1197
# Out:
# 0.003341687552213868

# %%
slot=6148669 ms=3412
slot=6148694 ms=7036
slot=6149120 ms=3722
slot=6152544 ms=3787

# %%
res3 = []
for s in slots:
    time.sleep(0.1)
    url = 'http://57.128.92.65:3500/eth/v2/beacon/blocks/{}'.format(s)
    headers = {'content-type': 'application/json'}
    r = requests.get(url, headers=headers)
    try: 
        code = r.json()['code']
        print(s, False)
        res3.append((s, False))
    except KeyError:
        print(s, True)
        res3.append((s, True))
# Out:
# 6156033 True
# 6156323 True
# 6155942 True
# 6155206 True
# 6154758 True
# 6154798 True
# 6155184 True
# 6155474 True
# 6156084 True
# 6155444 True
# 6155382 True
# 6154806 True
# 6155065 True
# 6156253 True
# 6155262 True
# 6156063 False

# %%
t.keys()
# Out:
# Index(['insertId', 'jsonPayload.blockHash', 'jsonPayload.contentLength',
#        'jsonPayload.headSlot', 'jsonPayload.idArg', 'jsonPayload.level',
#        'jsonPayload.method', 'jsonPayload.mevBoostV', 'jsonPayload.msIntoSlot',
#        'jsonPayload.msg', 'jsonPayload.pubkeyFromIndex',
#        'jsonPayload.requestTimestamp', 'jsonPayload.service',
#        'jsonPayload.slot', 'jsonPayload.slotStartSec', 'jsonPayload.ua',
#        'jsonPayload.version', 'labels."compute.googleapis.com/resource_name"',
#        'labels."k8s-pod/app"', 'labels."k8s-pod/pod-template-hash"',
#        'labels."k8s-pod/project"', 'logName', 'receiveLocation',
#        'receiveTimestamp', 'receivedLocation', 'resource.labels.cluster_name',
#        'resource.labels.container_name', 'resource.labels.location',
#        'resource.labels.namespace_name', 'resource.labels.pod_name',
#        'resource.labels.project_id', 'resource.type', 'severity', 'timestamp'],
#       dtype='object')

# %%
t = pd.read_csv('downloaded-logs-20230405-175450.csv', delimiter=',')
t = t[['jsonPayload.slot', 'jsonPayload.msIntoSlot']]
len(t)
# Out:
# 1292

# %%
t2 = t.sort_values('jsonPayload.msIntoSlot', ascending=True).drop_duplicates('jsonPayload.slot').sort_index()
len(t2)
# Out:
# 1057

# %%
t2.head()
# Out:
#    jsonPayload.slot  jsonPayload.msIntoSlot
# 0           6158966                     716
# 1           6158964                     990
# 2           6158962                    1204
# 3           6158961                    1208
# 4           6158959                    1774

# %%
f, ax = plt.subplots(figsize=(8,5))
ax.hist(t2['jsonPayload.msIntoSlot'], bins=300, color='k', alpha=0.7)
ax.set_xlabel('ms into slot', size=15)
plt.show()

# %%
t2[t2['jsonPayload.msIntoSlot'] > 4000]
# Out:
#       jsonPayload.slot  jsonPayload.msIntoSlot
# 99             6158759                    4831
# 118            6158720                    4482
# 454            6157864                    5537
# 545            6157598                    5524
# 554            6157584                    4914
# 695            6157184                   13973
# 697            6157170                    6147
# 703            6157155                    5623
# 765            6156919                    4037
# 814            6156731                    7484
# 838            6156607                   11316
# 860            6156520                    4172
# 876            6156433                    4066
# 951            6156084                    6787
# 975            6155942                    5332
# 1074           6155474                    7235
# 1081           6155444                    4404
# 1101           6155382                    6511
# 1148           6155206                    7108
# 1199           6155065                    7830

# %%
removals = pd.read_csv('downloaded-logs-20230405-181455.csv', delimiter=',')
removals = removals[['jsonPayload.slot', 'jsonPayload.msIntoSlot']]
len(removals)
# Out:
# 96

# %%
t2 = t2[~t2['jsonPayload.slot'].isin(removals['jsonPayload.slot'])]
len(t2)
# Out:
# 1023

# %%
    f, ax = plt.subplots(figsize=(8,5))
    ax.hist(t2['jsonPayload.msIntoSlot'], bins=300, color='k', alpha=0.7)
    ax.set_xlabel('ms into slot', size=15)
    plt.show()

# %%
t2[t2['jsonPayload.msIntoSlot'] > 4000]
# Out:
#       jsonPayload.slot  jsonPayload.msIntoSlot
# 99             6158759                    4831
# 118            6158720                    4482
# 454            6157864                    5537
# 545            6157598                    5524
# 554            6157584                    4914
# 695            6157184                   13973
# 697            6157170                    6147
# 703            6157155                    5623
# 765            6156919                    4037
# 814            6156731                    7484
# 838            6156607                   11316
# 860            6156520                    4172
# 876            6156433                    4066
# 951            6156084                    6787
# 975            6155942                    5332
# 1074           6155474                    7235
# 1081           6155444                    4404
# 1101           6155382                    6511
# 1148           6155206                    7108
# 1199           6155065                    7830
