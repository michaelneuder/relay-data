# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.3
plt.rcParams['axes.titlesize'] = 18

# %%
pka = pd.read_csv('decode_durs/pubkeya.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pka['received_at'] = pd.to_datetime(pka['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka['eligible_at'] = pd.to_datetime(pka['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6012053 2023-03-16 12:10:55.760036 2023-03-16 12:10:55.944087          f
# 1  6012053 2023-03-16 12:10:57.385221 2023-03-16 12:10:57.582350          f
# 2  6012053 2023-03-16 12:10:57.884796 2023-03-16 12:10:58.146450          f
# 3  6012053 2023-03-16 12:10:58.725586 2023-03-16 12:10:58.964325          f
# 4  6012053 2023-03-16 12:10:58.804853 2023-03-16 12:10:59.118235          f
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0           110367                1380                67897
# 1           102343                1874                88389
# 2           105312                2206               148267
# 3           107769                1589               123843
# 4           186473                1561               111729
#
#    redis_update_duration  total_duration
# 0                   4405          184050
# 1                   4521          197129
# ...

# %%
pkb = pd.read_csv('decode_durs/pubkeyb.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pkb['received_at'] = pd.to_datetime(pkb['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkb['eligible_at'] = pd.to_datetime(pkb['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkb.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6012053 2023-03-16 12:10:58.701198 2023-03-16 12:10:58.801983          f
# 1  6012053 2023-03-16 12:10:58.885416 2023-03-16 12:10:59.018903          f
# 2  6012053 2023-03-16 12:10:58.811966 2023-03-16 12:10:58.927534          f
# 3  6012053 2023-03-16 12:10:56.947012 2023-03-16 12:10:57.041144          f
# 4  6012053 2023-03-16 12:10:56.564883 2023-03-16 12:10:56.666451          f
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0             9936                1342                84231
# 1             8731                1847               116855
# 2            11236                1819                92661
# 3             8933                2410                77435
# 4             8300                1375                86642
#
#    redis_update_duration  total_duration
# 0                   5274          100785
# 1                   6052          133486
# ...

# %%
pkc = pd.read_csv('decode_durs/pubkeyc.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pkc['received_at'] = pd.to_datetime(pkc['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkc['eligible_at'] = pd.to_datetime(pkc['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6012053 2023-03-16 12:10:55.760036 2023-03-16 12:10:55.944087          f
# 1  6012053 2023-03-16 12:10:57.385221 2023-03-16 12:10:57.582350          f
# 2  6012053 2023-03-16 12:10:57.884796 2023-03-16 12:10:58.146450          f
# 3  6012053 2023-03-16 12:10:58.725586 2023-03-16 12:10:58.964325          f
# 4  6012053 2023-03-16 12:10:58.804853 2023-03-16 12:10:59.118235          f
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0           110367                1380                67897
# 1           102343                1874                88389
# 2           105312                2206               148267
# 3           107769                1589               123843
# 4           186473                1561               111729
#
#    redis_update_duration  total_duration
# 0                   4405          184050
# 1                   4521          197129
# ...

# %%
printdf(pka[pka['optimistic']=='f'])
# Out:
# decode\_duration & 138464 & 200748 & 293624 & 400298 \\
# prechecks\_duration & 1763 & 2418 & 5179 & 296829 \\
# simulation\_duration & 129669 & 166990 & 231593 & 714667 \\
# redis\_update\_duration & 7129 & 10955 & 29209 & 467807 \\
# \textbf{total\_duration} & \textbf{296517} & \textbf{406690} & \textbf{562900} & \textbf{1596849} \\

# %%
printdf(pkb[pkb['optimistic']=='f'])
# Out:
# decode\_duration & 15626 & 25349 & 36474 & 88924 \\
# prechecks\_duration & 1725 & 2278 & 4066 & 242843 \\
# simulation\_duration & 123699 & 156946 & 209962 & 606226 \\
# redis\_update\_duration & 6945 & 10345 & 23090 & 411211 \\
# \hline
# \textbf{total\_duration} & \textbf{154569} & \textbf{202073} & \textbf{309057} & \textbf{1217353} \\

# %%
printdf(pkc[pkc['optimistic']=='f'])
# Out:
# decode\_duration & 153334 & 228625 & 318582 & 419130 \\
# prechecks\_duration & 1873 & 2736 & 6839 & 290666 \\
# simulation\_duration & 139685 & 182880 & 267483 & 909616 \\
# redis\_update\_duration & 7895 & 12852 & 45489 & 470405 \\
# \hline
# \textbf{total\_duration} & \textbf{329005} & \textbf{464617} & \textbf{626499} & \textbf{1738598} \\

# %%
pka_2 = pd.read_csv('decode_durs/pubkeya_post.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pka_2['received_at'] = pd.to_datetime(pka_2['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_2['eligible_at'] = pd.to_datetime(pka_2['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_2.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6049146 2023-03-21 15:49:32.031570 2023-03-21 15:49:32.045923          t
# 1  6049146 2023-03-21 15:49:34.574787 2023-03-21 15:49:34.611724          t
# 2  6049146 2023-03-21 15:49:34.384231 2023-03-21 15:49:34.433168          t
# 3  6049146 2023-03-21 15:49:34.450051 2023-03-21 15:49:34.483979          t
# 4  6049146 2023-03-21 15:49:34.869539 2023-03-21 15:49:34.919059          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0             4436                1823                    2
# 1            30213                1508                    8
# 2            34991                5256                    3
# 3            27860                1445                    7
# 4            40943                1785                    8
#
#    redis_update_duration  total_duration
# 0                   8090           14352
# 1                   5206           36936
# ...

# %%
printdf(pka[pka['optimistic']=='t'])
# Out:
# decode\_duration & 136578 & 198185 & 294049 & 418546 \\
# prechecks\_duration & 1755 & 2422 & 5696 & 465805 \\
# simulation\_duration & 8 & 10 & 13 & 29 \\
# redis\_update\_duration & 7240 & 11613 & 30716 & 537172 \\
# \hline
# \textbf{total\_duration} & \textbf{151922} & \textbf{227457} & \textbf{344526} & \textbf{1335172} \\

# %%
printdf(pka_2[pka_2['optimistic']=='t'])
# Out:
# decode\_duration & 41591 & 114484 & 191925 & 323628 \\
# prechecks\_duration & 1778 & 2444 & 5067 & 375689 \\
# simulation\_duration & 8 & 10 & 13 & 30 \\
# redis\_update\_duration & 7254 & 11096 & 34570 & 1023302 \\
# \hline
# \textbf{total\_duration} & \textbf{53790} & \textbf{143288} & \textbf{236991} & \textbf{1924382} \\

# %%
len(pka_2[pka_2['optimistic']=='t'])
# Out:
# 3143

# %%
pka_3 = pd.read_csv('decode_durs/pubkeya_post_24.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pka_3['received_at'] = pd.to_datetime(pka_3['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3['eligible_at'] = pd.to_datetime(pka_3['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6049146 2023-03-21 15:49:32.031570 2023-03-21 15:49:32.045923          t
# 1  6049146 2023-03-21 15:49:34.574787 2023-03-21 15:49:34.611724          t
# 2  6049146 2023-03-21 15:49:34.384231 2023-03-21 15:49:34.433168          t
# 3  6049146 2023-03-21 15:49:34.450051 2023-03-21 15:49:34.483979          t
# 4  6049146 2023-03-21 15:49:34.869539 2023-03-21 15:49:34.919059          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0             4436                1823                    2
# 1            30213                1508                    8
# 2            34991                5256                    3
# 3            27860                1445                    7
# 4            40943                1785                    8
#
#    redis_update_duration  total_duration
# 0                   8090           14352
# 1                   5206           36936
# ...

# %%
printdf(pka_3[pka_3['optimistic']=='t'])
# Out:
# decode\_duration & 46674 & 117271 & 201648 & 364637 \\
# prechecks\_duration & 1773 & 2489 & 7590 & 420413 \\
# simulation\_duration & 8 & 10 & 13 & 30 \\
# redis\_update\_duration & 7183 & 11453 & 38003 & 1002830 \\
# \hline
# \textbf{total\_duration} & \textbf{59741} & \textbf{146262} & \textbf{262586} & \textbf{1678931} \\

# %%
len(pka_3[pka_3['optimistic']=='t'])
# Out:
# 110387

# %%
pkb_2 = pd.read_csv('decode_durs/pubkeyb_post_24.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pkb_2['received_at'] = pd.to_datetime(pkb_2['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkb_2['eligible_at'] = pd.to_datetime(pkb_2['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkb_2.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6049156 2023-03-21 15:51:33.313830 2023-03-21 15:51:33.399065          t
# 1  6049156 2023-03-21 15:51:33.569183 2023-03-21 15:51:33.641162          t
# 2  6049156 2023-03-21 15:51:34.376325 2023-03-21 15:51:34.420772          t
# 3  6049156 2023-03-21 15:51:35.507006 2023-03-21 15:51:35.564192          t
# 4  6049156 2023-03-21 15:51:33.313862 2023-03-21 15:51:33.415191          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0            78675                1319                    8
# 1            43502               18313                    4
# 2            38106                1281                    7
# 3            50669                1448                   11
# 4            95093                1394                    7
#
#    redis_update_duration  total_duration
# 0                   5231           85234
# 1                  10157           71978
# ...

# %%
f, ax = plt.subplots(figsize=(12,5))
ax.plot(pkb_2['slot'],pkb_2['decode_duration'], 'g,', linewidth=2, alpha=0.7)
ax.set_xlabel('slot', size=15)
ax.set_ylabel('decode duration', size=15)
plt.show()

# %%
printdf(pkb_2[pkb_2['optimistic']=='t'])
# Out:
# decode\_duration & 135947 & 215863 & 316279 & 565913 \\
# prechecks\_duration & 1911 & 3118 & 25881 & 558087 \\
# simulation\_duration & 8 & 10 & 13 & 31 \\
# redis\_update\_duration & 8272 & 16128 & 95708 & 1656978 \\
# \hline
# \textbf{total\_duration} & \textbf{156580} & \textbf{258562} & \textbf{424501} & \textbf{2622449} \\

# %%
len(pkb_2[pkb_2['optimistic']=='t'])
# Out:
# 32128

# %%
pkc_3 = pd.read_csv('decode_durs/pubkeyc_post_24.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pkc_3['received_at'] = pd.to_datetime(pkc_3['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkc_3['eligible_at'] = pd.to_datetime(pkc_3['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkc_3.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6049146 2023-03-21 15:49:32.165996 2023-03-21 15:49:32.175815          t
# 1  6049146 2023-03-21 15:49:32.286457 2023-03-21 15:49:32.296793          t
# 2  6049146 2023-03-21 15:49:32.359065 2023-03-21 15:49:32.367673          t
# 3  6049146 2023-03-21 15:49:32.123753 2023-03-21 15:49:32.134444          t
# 4  6049146 2023-03-21 15:49:33.405575 2023-03-21 15:49:33.415653          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0             3157                1846                   10
# 1             3745                1372                   10
# 2             3244                1503                    8
# 3             3801                1932                   11
# 4             4354                1427                   10
#
#    redis_update_duration  total_duration
# 0                   4804            9819
# 1                   5207           10335
# ...

# %%
printdf(pkc_3[pkc_3['optimistic']=='t'])
# Out:
# decode\_duration & 9676 & 20646 & 32027 & 155801 \\
# prechecks\_duration & 1737 & 2341 & 4897 & 376049 \\
# simulation\_duration & 8 & 10 & 13 & 29 \\
# redis\_update\_duration & 6755 & 10168 & 25128 & 724544 \\
# \hline
# \textbf{total\_duration} & \textbf{20011} & \textbf{35058} & \textbf{68957} & \textbf{1200496} \\

# %%
len(pkc_3[pkc_3['optimistic']=='t'])
# Out:
# 191061

# %%
f, ax = plt.subplots(figsize=(12,5))
ax.plot(pkc_3['slot'],pkc_3['decode_duration'], 'g,', linewidth=2, alpha=0.7)
ax.set_xlabel('slot', size=15)
ax.set_ylabel('decode duration', size=15)
plt.show()

# %%
pkc_3 = pd.read_csv('decode_durs/pubkeyc_post_24_2.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pkc_3['received_at'] = pd.to_datetime(pkc_3['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkc_3['eligible_at'] = pd.to_datetime(pkc_3['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pkc_3.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6047837 2023-03-21 11:27:44.218033 2023-03-21 11:27:44.232035          t
# 1  6047837 2023-03-21 11:27:44.271644 2023-03-21 11:27:44.283869          t
# 2  6047837 2023-03-21 11:27:45.216810 2023-03-21 11:27:45.231880          t
# 3  6047837 2023-03-21 11:27:45.673657 2023-03-21 11:27:45.694297          t
# 4  6047837 2023-03-21 11:27:43.556773 2023-03-21 11:27:43.565609          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0             4610                3506                    2
# 1             6150                1734                    9
# 2             8879                1388                   10
# 3            12842                1916                   13
# 4             3106                1289                    8
#
#    redis_update_duration  total_duration
# 0                   5882           14002
# 1                   4330           12225
# ...

# %%
printdf(pkc_3[pkc_3['optimistic']=='t'])
# Out:
# decode\_duration & 11286 & 21637 & 33362 & 149842 \\
# prechecks\_duration & 1739 & 2347 & 4867 & 360851 \\
# simulation\_duration & 8 & 10 & 13 & 29 \\
# redis\_update\_duration & 6872 & 10368 & 25399 & 678884 \\
# \hline
# \textbf{total\_duration} & \textbf{21406} & \textbf{36311} & \textbf{70378} & \textbf{1124777} \\

# %%
len(pkc_3[pkc_3['optimistic']=='t'])
# Out:
# 237403

# %%
durs = pkc_3['decode_duration'].values

N = 10000
durs_mean = np.convolve(durs, np.ones(N)/N, mode='valid')

# %%
durs_med = pkc_3['decode_duration'].rolling(N).median()
durs_90 = pkc_3['decode_duration'].rolling(N).quantile(0.9)
len(durs_med), len(durs)
# Out:
# (237673, 237673)

# %%
f, ax = plt.subplots(figsize=(12,5))
ax.plot(pkc_3['slot'],pkc_3['decode_duration'], 'g,', linewidth=2, alpha=0.7, label='raw data')
ax.plot(pkc_3['slot'], durs_med, 'k', linewidth=2, alpha=0.7, label='rolling p50')
ax.plot(pkc_3['slot'], durs_90, 'b', linewidth=2, alpha=0.7, label='rolling p90')
ax.set_xlabel('slot', size=15)
ax.set_ylabel('decode duration', size=15)
ax.set_ylim(0,50000)
ax.legend()
ax.set_title('0x978 decode durations')
plt.show()

# %%
pka_3 = pd.read_csv('decode_durs/pubkeya_post_24_2.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pka_3['received_at'] = pd.to_datetime(pka_3['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3['eligible_at'] = pd.to_datetime(pka_3['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6047837 2023-03-21 11:27:45.238238 2023-03-21 11:27:45.331507          t
# 1  6047840 2023-03-21 11:28:20.872382 2023-03-21 11:28:21.052374          t
# 2  6047840 2023-03-21 11:28:20.317964 2023-03-21 11:28:20.528836          t
# 3  6047840 2023-03-21 11:28:21.148393 2023-03-21 11:28:21.587218          t
# 4  6047840 2023-03-21 11:28:20.346752 2023-03-21 11:28:20.537681          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0            83450                1854                    3
# 1           107777               56322                    3
# 2           111504               72455                    2
# 3           101467              278660                    3
# 4           183409                2011                    3
#
#    redis_update_duration  total_duration
# 0                   7960           93268
# 1                  15888          179991
# ...

# %%
len(pka_3[pka_3['optimistic']=='t'])
# Out:
# 137128

# %%
durs = pka_3['decode_duration'].values
N = 1000

# %%
durs_med = pka_3['decode_duration'].rolling(N).median()
durs_90 = pka_3['decode_duration'].rolling(N).quantile(0.9)
durs_99 = pka_3['decode_duration'].rolling(N).quantile(0.99)
len(durs_med), len(durs)
# Out:
# (137364, 137364)

# %%
f, ax = plt.subplots(figsize=(12,5))
ax.plot(pka_3['slot'],pka_3['decode_duration'], 'g,', linewidth=2, alpha=0.7, label='raw data')
ax.plot(pka_3['slot'], durs_med, 'k', linewidth=2, alpha=0.7, label='rolling p50')
ax.plot(pka_3['slot'], durs_90, 'b', linewidth=2, alpha=0.7, label='rolling p90')
# ax.plot(pka_3['slot'], durs_99, 'purple', linewidth=2, alpha=0.7, label='rolling p99')
ax.set_xlabel('slot', size=15)
ax.set_ylabel('decode duration', size=15)
ax.set_ylim(0,500000)
ax.legend(loc=0)
ax.set_title('0x83d decode durations')
plt.show()

# %%
pka_3 = pd.read_csv('decode_durs/pubkeyb_post_24_2.txt', delimiter="|", 
                  names=['slot', 'received_at', 'eligible_at', 'optimistic', 'decode_duration',
                         'prechecks_duration', 'simulation_duration', 'redis_update_duration', 'total_duration'])
pka_3['received_at'] = pd.to_datetime(pka_3['received_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3['eligible_at'] = pd.to_datetime(pka_3['eligible_at'], format="%Y-%m-%d%H:%M:%S.%f")
pka_3.head()
# Out:
#       slot                received_at                eligible_at optimistic  \
# 0  6047837 2023-03-21 11:27:45.735363 2023-03-21 11:27:45.912935          t
# 1  6047837 2023-03-21 11:27:47.141547 2023-03-21 11:27:47.279347          t
# 2  6047837 2023-03-21 11:27:45.665701 2023-03-21 11:27:45.858216          t
# 3  6047837 2023-03-21 11:27:45.888879 2023-03-21 11:27:45.995991          t
# 4  6047837 2023-03-21 11:27:45.509154 2023-03-21 11:27:45.686746          t
#
#    decode_duration  prechecks_duration  simulation_duration  \
# 0           153063                2343                    2
# 1           130861                2225                    2
# 2           184861                2048                    3
# 3            99425                2010                   12
# 4           167477                2062                   14
#
#    redis_update_duration  total_duration
# 0                  22162          177572
# 1                   4709          137800
# ...

# %%
len(pka_3[pka_3['optimistic']=='f'])
# Out:
# 101

# %%
durs = pka_3['decode_duration'].values
N = 1000

# %%
durs_med = pka_3['decode_duration'].rolling(N).median()
durs_90 = pka_3['decode_duration'].rolling(N).quantile(0.9)
durs_99 = pka_3['decode_duration'].rolling(N).quantile(0.99)
len(durs_med), len(durs)
# Out:
# (42730, 42730)

# %%
f, ax = plt.subplots(figsize=(12,5))
ax.plot(pka_3['slot'],pka_3['decode_duration'], 'g,', linewidth=2, alpha=0.7, label='raw data')
ax.plot(pka_3['slot'], durs_med, 'k', linewidth=2, alpha=0.7, label='rolling p50')
ax.plot(pka_3['slot'], durs_90, 'b', linewidth=2, alpha=0.7, label='rolling p90')
# ax.plot(pka_3['slot'], durs_99, 'purple', linewidth=2, alpha=0.7, label='rolling p99')
ax.set_xlabel('slot', size=15)
ax.set_ylabel('decode duration', size=15)
ax.set_ylim(0,500000)
ax.legend(loc=2)
ax.set_title('0x945 decode durations')
plt.show()

# %%
def printdf(df):
    print('decode\_duration & ', end='')
    st = ''
    for i in [50, 75, 90, 99]:
        st += str(int(np.percentile(df['decode_duration'], i)))
        st += " & "
    print(st[:-3] + ' \\\\')
    st = ''
    print('prechecks\_duration & ', end='')
    for i in [50, 75, 90, 99]:
        st += str(int(np.percentile(df['prechecks_duration'], i)))
        st += " & "
    print(st[:-3] + ' \\\\')
    st = ''
    print('simulation\_duration & ', end='')
    for i in [50, 75, 90, 99]:
        st += str(int(np.percentile(df['simulation_duration'], i)))
        st += " & "
    print(st[:-3] + ' \\\\')
    st = ''
    print('redis\_update\_duration & ', end='')
    for i in [50, 75, 90, 99]:
        st += str(int(np.percentile(df['redis_update_duration'], i)))
        st += " & "
    print(st[:-3] + ' \\\\')
    st = ''
    print('\\hline')
    print('\\textbf{total\_duration} & ', end='')
    for i in [50, 75, 90, 99]:
        st += '\\textbf{{{}}}'.format(str(int(np.percentile(df['total_duration'], i))))
        st += " & "
    print(st[:-3] + ' \\\\')
